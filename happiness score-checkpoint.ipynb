# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # importing datadset

# %%
df= pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head(15)
# Out:
#           Country                           Region  Happiness Rank  \
# 0     Switzerland                   Western Europe               1
# 1         Iceland                   Western Europe               2
# 2         Denmark                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4          Canada                    North America               5
# 5         Finland                   Western Europe               6
# 6     Netherlands                   Western Europe               7
# 7          Sweden                   Western Europe               8
# 8     New Zealand        Australia and New Zealand               9
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# 11     Costa Rica      Latin America and Caribbean              12
# 12        Austria                   Western Europe              13
# ...

# %%
df.tail(15)
# Out:
#                       Country                           Region  \
# 143                     Niger               Sub-Saharan Africa
# 144                  Cambodia                Southeastern Asia
# 145                  Tanzania               Sub-Saharan Africa
# 146                Madagascar               Sub-Saharan Africa
# 147  Central African Republic               Sub-Saharan Africa
# 148                      Chad               Sub-Saharan Africa
# 149                    Guinea               Sub-Saharan Africa
# 150               Ivory Coast               Sub-Saharan Africa
# 151              Burkina Faso               Sub-Saharan Africa
# 152               Afghanistan                    Southern Asia
# 153                    Rwanda               Sub-Saharan Africa
# 154                     Benin               Sub-Saharan Africa
# 155                     Syria  Middle East and Northern Africa
# 156                   Burundi               Sub-Saharan Africa
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# From the above dataset we can observe that there is 12 columns and 158 rows in the dataset, out of which one is target variable i.e. the column 'happiness score' is our target column and the rest columns are the independent variable.

# %% [markdown]
# # Exploratory data Analysis(EDA)

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# This data set contains 12 columns and 158 rows, havimg both object and numerical data.

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %% [markdown]
# #checking the null values

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# As we can see that there is no null values present in the dataset, lets viasualize it using haetmap

# %%
#visualising using heat map
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# From the above heatmap also we can visualize that there is no null values in the dataset.

# %% [markdown]
# As i think the column happiness rank does not help us in predicating the happiness score of the countries so we drop the column happiness rank

# %%
#dropping happiness rank column
df.drop('Happiness Rank', axis = 1, inplace=True)
df
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
# checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64
#
#
# 0.03780    2
# 0.03751    2
# 0.04394    2
# 0.05051    2
# 0.04934    2
#           ..
# 0.04114    1
# ...

# %%
# seprating numerical and categorical column

categorical_column=[]
for i in df.dtypes.index:
    if df.dtypes[i]== 'object':
        categorical_column.append(i)
print("Categorical Columns:", categorical_column)
print("\n")

#checking for numericals columns
numerical_column=[]
for i in df.dtypes.index:
    if df.dtypes[i]!= 'object':
        numerical_column.append(i)
print("Numerical Columns", numerical_column)
# Out:
# Categorical Columns: ['Country', 'Region']
#
#
# Numerical Columns ['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
#checking number of unique values in each column
df.nunique().to_frame("No. of Unique values")
# Out:
#                                No. of Unique values
# Country                                         158
# Region                                           10
# Happiness Score                                 157
# Standard Error                                  153
# Economy (GDP per Capita)                        158
# Family                                          158
# Health (Life Expectancy)                        157
# Freedom                                         158
# Trust (Government Corruption)                   157
# Generosity                                      158
# Dystopia Residual                               158

# %% [markdown]
# # Description of datasets

# %%
#stastical summary of theb datasets
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# From the above stastical summary we can observe that
# 1) the value counts of each column is similar it means no null values are missing in the dataset.
# 2) The difference between the mean and the median value of the columns are very less, it means there is a least skewness in the dataset
# 3) the difference between the the 75% value and the max value are very less it means there is a probability of no outliers.

# %% [markdown]
# # Data Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Score                158 non-null    float64
#  3   Standard Error                 158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 13.7+ KB

# %%
#visualizing the column region
ax= sns.countplot(y='Region', data=df)
print(df['Region'].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# From the above graph we can observe that
# 1) the maximum count is for the region Sub saharan africa.
# 2) the least count is for the region north america, Australia and newzealand.

# %%
#Let's check all columns by pair plot 
import seaborn as sns 
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(df, kind="reg")

# %% [markdown]
# Scatterplots show possible associations or relationships between two variables. we can see from the above plots that there is positive and negative relationships, uphill lines are showing positive, downhill lines are negative relationships. In above plots we are seeing that we have weaker, stronger relationships.

# %%
#lets visualize the target variable with our independent variable.
sns.lmplot(x='Standard Error', y='Happiness Score', data=df, palette='colorblind')

# %% [markdown]
# standard error does not have a specific relation with happiness score

# %%
#lets visualize the target variable with our independent variable.
sns.lmplot(x='Economy (GDP per Capita)', y='Happiness Score', data=df, palette='colorblind')

# %% [markdown]
# economy has a positive relation with happiness score

# %%
sns.lmplot(x='Family', y='Happiness Score', data=df, palette='colorblind')

# %% [markdown]
# the column family  has a relation with happiness score

# %%
sns.lmplot(x='Health (Life Expectancy)', y='Happiness Score', data=df, palette='colorblind')

# %% [markdown]
# Health has a relationship with happiness score

# %%
sns.lmplot(x='Freedom', y='Happiness Score', data=df, palette='colorblind')

# %% [markdown]
# the column has not a specific relation with happiness score

# %%
sns.lmplot(x='Trust (Government Corruption)', y='Happiness Score', data=df, palette='colorblind')

# %% [markdown]
# in the early stage the trust has a relation with happiness score but later it does not relationship.

# %%
sns.lmplot(x='Generosity', y='Happiness Score', data=df, palette='colorblind')

# %% [markdown]
# in the somewhere part the generosity has a relation with happiness score

# %%
sns.lmplot(x='Dystopia Residual', y='Happiness Score', data=df, palette='colorblind')

# %% [markdown]
# In the middle part it has relation with happiness score

# %% [markdown]
# # converting categorical column into numerical column

# %%
#enconding categorical column using ordinal encoding
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]= OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Country  Region  Happiness Score  Standard Error  \
# 0      135.0     9.0            7.587         0.03411
# 1       58.0     9.0            7.561         0.04884
# 2       37.0     9.0            7.527         0.03328
# 3      105.0     9.0            7.522         0.03880
# 4       24.0     5.0            7.427         0.03553
# ..       ...     ...              ...             ...
# 153    118.0     8.0            3.465         0.03464
# 154     13.0     8.0            3.340         0.03656
# 155    136.0     4.0            3.006         0.05015
# 156     21.0     8.0            2.905         0.08658
# 157    141.0     8.0            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %% [markdown]
# # Checking Outliers

# %%
#checking outliers
plt.figure(figsize= (20,15), facecolor='white')
plotnumber = 1
for column in df:
    if plotnumber<=12:
        ax = plt.subplot(3,4, plotnumber)
        sns.boxplot(df[column], palette = 'Set2_r')
        plt.xlabel(column, fontsize=20)
        plt.yticks(rotation = 0, fontsize = 20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# from the above bar plot we can see the outliers in the columns standard error, family, trust, generosity, dystopia residual.

# %% [markdown]
# Before that we can seprate the feature and the target column

# %%
#divide dataset into feature and label
y= df['Happiness Score']
x=df.drop(columns = ['Happiness Score'])
x
# Out:
#      Country  Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0      135.0     9.0         0.03411                   1.39651  1.34951
# 1       58.0     9.0         0.04884                   1.30232  1.40223
# 2       37.0     9.0         0.03328                   1.32548  1.36058
# 3      105.0     9.0         0.03880                   1.45900  1.33095
# 4       24.0     5.0         0.03553                   1.32629  1.32261
# ..       ...     ...             ...                       ...      ...
# 153    118.0     8.0         0.03464                   0.22208  0.77370
# 154     13.0     8.0         0.03656                   0.28665  0.35386
# 155    136.0     4.0         0.05015                   0.66320  0.47489
# 156     21.0     8.0         0.08658                   0.01530  0.41587
# 157    141.0     8.0         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# so, now removing the outliers from the featured column.

# %%
from scipy.stats import zscore
out_features= x
z=np.abs(zscore(x))
z
# Out:
#       Country    Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0    1.238770  1.300256        0.805926                  1.369621  1.320281
# 1    0.449465  1.300256        0.055889                  1.135226  1.514458
# 2    0.909893  1.300256        0.854487                  1.192861  1.361054
# 3    0.581016  1.300256        0.531526                  1.525130  1.251922
# 4    1.194920  0.040302        0.722845                  1.194876  1.221204
# ..        ...       ...             ...                       ...       ...
# 153  0.866043  0.965117        0.774917                  1.552987  0.800520
# 154  1.436096  0.965117        0.662582                  1.392303  2.346860
# 155  1.260695  0.375441        0.132534                  0.455245  1.901086
# 156  1.260695  0.965117        2.263962                  2.067566  2.118467
# 157  1.370321  0.965117        1.134182                  1.586334  3.134725
#
# ...

# %%
#treshold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
#now removing the data above zscore and creating new dataframe
df1= df[(z<3).all(axis=1)]

df1.shape
# Out:
# (149, 11)

# %%
print("Data loss percentage- ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  5.69620253164557

# %%
df1
# Out:
#      Country  Region  Happiness Score  Standard Error  \
# 0      135.0     9.0            7.587         0.03411
# 1       58.0     9.0            7.561         0.04884
# 2       37.0     9.0            7.527         0.03328
# 3      105.0     9.0            7.522         0.03880
# 4       24.0     5.0            7.427         0.03553
# ..       ...     ...              ...             ...
# 150     66.0     8.0            3.655         0.05141
# 151     20.0     8.0            3.587         0.04324
# 152      0.0     7.0            3.575         0.03084
# 154     13.0     8.0            3.340         0.03656
# 156     21.0     8.0            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
#now using IQR method

#1st quantile
Q1 = x.quantile(0.25)

#3rd quantile
Q3 = x.quantile(0.75)

#IQR
IQR = Q3 - Q1

df2= df[~((df <(Q1 - 1.5 * IQR))|(df> (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (126, 11)

# %%
print("Data loss percentage- ",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  20.253164556962027

# %% [markdown]
# As we see that the zscore method will give the less amount of loss percentage data so we used df1 as our new dataframe

# %%
df = df1

# %%
df
# Out:
#      Country  Region  Happiness Score  Standard Error  \
# 0      135.0     9.0            7.587         0.03411
# 1       58.0     9.0            7.561         0.04884
# 2       37.0     9.0            7.527         0.03328
# 3      105.0     9.0            7.522         0.03880
# 4       24.0     5.0            7.427         0.03553
# ..       ...     ...              ...             ...
# 150     66.0     8.0            3.655         0.05141
# 151     20.0     8.0            3.587         0.04324
# 152      0.0     7.0            3.575         0.03084
# 154     13.0     8.0            3.340         0.03656
# 156     21.0     8.0            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
#Now checking the skewness of the data
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# From the above information we can see that there is a skewness in the column standard error,family, health,trust and in the column generosity.so now we remove these skewness using cube root method.

# %%
#removing skewness from the column standard error using cbrt method.
df['Standard Error']= np.cbrt(df['Standard Error'])
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#df['Family']= np.cbrt(df['Family'])
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#removing skewness from the column family
df['Family']= np.log10(df['Family'])
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -1.611713
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
# removing skewness from the column health
df['Health (Life Expectancy)']= np.cbrt(df['Health (Life Expectancy)'])
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -1.611713
# Health (Life Expectancy)        -2.067331
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#removing skewness from the column trust
df['Trust (Government Corruption)']= np.cbrt(df['Trust (Government Corruption)'])
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -1.611713
# Health (Life Expectancy)        -2.067331
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#removing skewness from the column generosity
df['Generosity']= np.cbrt(df['Generosity'])
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -1.611713
# Health (Life Expectancy)        -2.067331
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                      -1.087392
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#final skewness table
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -1.611713
# Health (Life Expectancy)        -2.067331
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                      -1.087392
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#Now checking the skewness of the data
plt.figure(figsize=(20,25), facecolor="Blue")

p=1
for column in df:
    if p<=12:
        ax= plt.subplot(3,4,p)
        sns.distplot(df[column],color="g" )
        plt.xlabel(column,fontsize=25)
    p+=1
plt.show()

# %% [markdown]
# From the above graph we can see that we remove the skewness from the data

# %% [markdown]
# # correlation between target variable and independent variable

# %%
#checking the correlation
df.corr()
# Out:
#                                 Country    Region  Happiness Score  \
# Country                        1.000000  0.007739         0.120109
# Region                         0.007739  1.000000        -0.145850
# Happiness Score                0.120109 -0.145850         1.000000
# Standard Error                -0.004480 -0.047835        -0.237228
# Economy (GDP per Capita)       0.039300 -0.224928         0.773577
# Family                         0.221999 -0.146619         0.663219
# Health (Life Expectancy)       0.023662 -0.365242         0.623803
# Freedom                        0.091495  0.101335         0.585066
# Trust (Government Corruption)  0.044064  0.211246         0.394775
# Generosity                     0.095940  0.286203         0.205512
# Dystopia Residual              0.048980 -0.059494         0.528334
#
#                                Standard Error  Economy (GDP per Capita)  \
# Country                             -0.004480                  0.039300
# ...

# %% [markdown]
# Now we can analyze this correlation withe the help of heatmap

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=15)
plt.title('Descriptive graph', fontsize=25)
plt.show()

# %% [markdown]
# From the above heatmap we can observed that
# 1) the happiness score will have a strong positive correlation with the column economy.
# 2) the happiness score will have a negative correlation with the column standard error.
# 3) we can also observed that the column health and region and the column health and standard error have a negative coorelation.

# %%
#visualizing the correlation between target and label using bar plot
plt.figure(figsize=(22,8))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind="bar",color="r")
plt.xlabel("Feature", fontsize = 17)
plt.ylabel("Target", fontsize= 17)
plt.title("correlation between label and feature", fontsize = 23)
plt.show()

# %% [markdown]
# From the above graph we can observe that the column economy has a strong correlation with the target column and the column country has less correlation with the the target column.

# %% [markdown]
# # Feature scaling and standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#       Country    Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0    1.238770  1.300256       -0.805926                  1.369621  1.320281
# 1   -0.449465  1.300256        0.055889                  1.135226  1.514458
# 2   -0.909893  1.300256       -0.854487                  1.192861  1.361054
# 3    0.581016  1.300256       -0.531526                  1.525130  1.251922
# 4   -1.194920 -0.040302       -0.722845                  1.194876  1.221204
# ..        ...       ...             ...                       ...       ...
# 153  0.866043  0.965117       -0.774917                 -1.552987 -0.800520
# 154 -1.436096  0.965117       -0.662582                 -1.392303 -2.346860
# 155  1.260695 -0.375441        0.132534                 -0.455245 -1.901086
# 156 -1.260695  0.965117        2.263962                 -2.067566 -2.118467
# 157  1.370321  0.965117        1.134182                 -1.586334 -3.134725
#
# ...

# %% [markdown]
# We have scaled the data using standard scalarization method to overcome the issue of biasness

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)¶

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#    VIF values                       Features
# 0    1.053610                        Country
# 1    1.397756                         Region
# 2    1.160995                 Standard Error
# 3    4.158948       Economy (GDP per Capita)
# 4    2.009439                         Family
# 5    3.819824       Health (Life Expectancy)
# 6    1.763865                        Freedom
# 7    1.472035  Trust (Government Corruption)
# 8    1.394163                     Generosity
# 9    1.057979              Dystopia Residual

# %% [markdown]
# For the VIF if we can take the threshold value as 5, so we can observe that no column has the value greater than 5, it means there is no problem of multicollinearity.

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# Finding the best random State

# %%
# creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=40, random_state=i)
    lr= LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is", maxAccu,"On Random State", maxRs)
# Out:
# Maximum r2 score is 0.9999999656085987 On Random State 72

# %% [markdown]
# The Best Accuracy score is 99.99% at random state 72

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.40, random_state = maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR= LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_LR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.9999999397143964
# R2_score on training data: 99.99999282929653
# Mean Absolute Error: 0.00026852806098298654
# Mean Squared Error: 1.0453508756666977e-07
# Root Mean Squared Error: 0.0003233188636109402

# %% [markdown]
# The best R2 score is 99.99%

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_RFR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.8587670238401233
# R2_score on training data: 98.12547118553154
# Mean Absolute Error: 0.00026852806098298654
# Mean Squared Error: 0.24489763144062499
# Root Mean Squared Error: 0.4948713281658425

# %% [markdown]
# The Best R2 score at Random forest regressor is 85.90%

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print("R2_score:" , r2_score(y_test,pred_knn))
print("R2_score on training data: ", r2_score(y_train,pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:", mean_squared_error(y_test, pred_knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score: 0.8474630783325416
# R2_score on training data:  89.94559293862696
# Mean Aboslute Error: 0.4160374999999999
# Mean Squared Error: 0.264498645
# Root Mean Squared Error: 0.5142943174875647

# %% [markdown]
# The Best R2 score at knn is 84.74%

# %%
gbr= GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_gbr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_gbr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_gbr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_gbr)))
# Out:
# R2_score: 0.9139198349007724
# R2_score on training Data: 99.96321627201189
# Mean Aboslute Error: 0.27666105606909774
# Mean Squared Error: 0.14926279343540227
# Root Mean Squared Error: 0.38634543278703615

# %% [markdown]
# The best R2 score at GradientBoosting regressor is 91.13%

# %%
lasso= Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print("R2_score:", r2_score(y_test, pred_lasso))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:", mean_squared_error(y_test, pred_lasso))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_score: -0.006637994039999429
# R2_score on training Data: 0.0
# Mean Aboslute Error: 1.1439601063829787
# Mean Squared Error: 1.7455077925956315
# Root Mean Squared Error: 1.3211766697136427

# %%
rd= Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print("R2_score:", r2_score(y_test, pred_rd))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:", mean_squared_error(y_test, pred_rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score: 0.9999053549875698
# R2_score on training Data: 99.99233046073267
# Mean Aboslute Error: 0.01046906144380512
# Mean Squared Error: 0.00016411421752931374
# Root Mean Squared Error: 0.012810707143999263

# %% [markdown]
# The Best R2 score at Ridge is 99.99%

# %%
from sklearn.tree import DecisionTreeRegressor
dtr= DecisionTreeRegressor()
dtr.fit(x_train, y_train)
pred_dtr = dtr.predict(x_test)
pred_train = rd.predict(x_train)
print("R2_score:", r2_score(y_test, pred_dtr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_dtr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_dtr)))
# Out:
# R2_score: 0.8172406833760285
# R2_score on training Data: 99.99233046073267
# Mean Aboslute Error: 0.4005468750000001
# Mean Squared Error: 0.31690420312500006
# Root Mean Squared Error: 0.5629424509885536

# %% [markdown]
# The best R2 score at DecisionTreeRegressor is 72.89%

# %%
tr= ExtraTreesRegressor()
tr.fit(x_train, y_train)
pred_tr = tr.predict(x_test)
pred_train = tr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_tr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_tr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_tr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_tr)))
# Out:
# R2_score: 0.8936232140721745
# R2_score on training Data: 100.0
# Mean Aboslute Error: 0.31034343749999976
# Mean Squared Error: 0.1844570837656248
# Root Mean Squared Error: 0.4294846723290888

# %% [markdown]
# The best R2 score at ExtraTreesRegressor is 88.16%

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()
xgb.fit(x_train,y_train)
pred_xgb = xgb.predict(x_test)
pred_train = xgb.predict(x_train)
print("R2_score:", r2_score(y_test, pred_xgb))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_xgb))
print("Mean Squared Error:", mean_squared_error(y_test, pred_xgb))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_xgb)))
# Out:
# R2_score: 0.8375678378177431
# R2_score on training Data: 99.99996606688389
# Mean Aboslute Error: 0.4095011964440346
# Mean Squared Error: 0.2816569675851324
# Root Mean Squared Error: 0.5307136399086917

# %% [markdown]
# The best R2 score at xgboost is 83.75%

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(x_train, y_train)
pred_ada = ada.predict(x_test)
pred_train = ada.predict(x_train)
print("R2_score:", r2_score(y_test, pred_ada))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_ada))
print("Mean Squared Error:", mean_squared_error(y_test, pred_ada))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_ada)))
# Out:
# R2_score: 0.8477055347719653
# R2_score on training Data: 96.21052245746819
# Mean Aboslute Error: 0.3983283549785595
# Mean Squared Error: 0.2640782261335509
# Root Mean Squared Error: 0.5138854212113347

# %% [markdown]
# The best R2 score at AdaBoostRegressor is 84.77%

# %% [markdown]
# # Cross validation of the models

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between cross validation score and R2 score at LinearRegression is:",(r2_score(y_test,pred_LR)- score.mean())*100)
# Out:
# [0.99999952 0.9999984  0.99999832 0.99999554 0.99999933]
# 0.9999982233020892
# Difference between cross validation score and R2 score at LinearRegression is: 0.00017164123071733428

# %%
score1= cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between cross validation score and R2 score at RandomForestRegressor is:",(r2_score(y_test,pred_RFR)- score.mean())*100)
# Out:
# [-8.00707139 -1.14282389 -1.04158699 -1.74342014 -5.5481049 ]
# -3.496601463113019
# Difference between cross validation score and R2 score at RandomForestRegressor is: -14.123119946196594

# %%
score3= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between cross validation score and R2 score at knn is:",(r2_score(y_test,pred_knn)- score.mean())*100)
# Out:
# [-9.61980769 -3.65704824 -2.5967033  -8.54231075 -5.04237068]
# -5.891648131812409
# Difference between cross validation score and R2 score at knn is: -15.253514496954757

# %%
score4= cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between cross validation score and R2 score at GradientBoostingRegressor is:",(r2_score(y_test,pred_gbr)- score.mean())*100)
# Out:
# [-4.08804004 -1.0126419  -2.53073073 -1.54045538 -3.93472585]
# -2.6213187807847547
# Difference between cross validation score and R2 score at GradientBoostingRegressor is: -8.607838840131677

# %%
score5= cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between cross validation score and R2 score at lasso is:",(r2_score(y_test,pred_lasso)- score.mean())*100)
# Out:
# [-39.5383371  -12.7569766   -0.20386211 -30.73906532 -23.65659767]
# -21.378967758942114
# Difference between cross validation score and R2 score at lasso is: -100.66362173420886

# %%
score6= cross_val_score(rd,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between cross validation score and R2 score at Ridge is:",(r2_score(y_test,pred_rd)- score.mean())*100)
# Out:
# [0.9940487  0.99962872 0.99954758 0.99931921 0.99807964]
# 0.9981247696318025
# Difference between cross validation score and R2 score at Ridge is: -0.009286831451937871

# %%
score7= cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print("Difference between cross validation score and R2 score at DecisionTreeRegressor is:",(r2_score(y_test,pred_dtr)- score.mean())*100)
# Out:
# [ -8.05730166  -7.98443386  -7.69624753 -11.3660817   -5.32901634]
# -8.086616218995118
# Difference between cross validation score and R2 score at DecisionTreeRegressor is: -18.27575399260607

# %%
score8= cross_val_score(tr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print("Difference between cross validation score and R2 score at ExtraTreesRegressor is:",(r2_score(y_test,pred_tr)- score.mean())*100)
# Out:
# [-7.0784692  -0.11973076 -1.25030938 -2.41290761 -4.8624357 ]
# -3.144770527331452
# Difference between cross validation score and R2 score at ExtraTreesRegressor is: -10.637500922991471

# %%
score9= cross_val_score(xgb,x,y,cv=5,scoring='r2')
print(score9)
print(score9.mean())
print("Difference between cross validation score and R2 score at xgbregressor is:",(r2_score(y_test,pred_xgb)- score.mean())*100)
# Out:
# [-5.54451582 -2.20016617 -2.90254571 -3.86374585 -5.72394498]
# -4.0469837080492415
# Difference between cross validation score and R2 score at xgbregressor is: -16.24303854843461

# %%
score10= cross_val_score(ada,x,y,cv=5,scoring='r2')
print(score10)
print(score10.mean())
print("Difference between cross validation score and R2 score at AdaBoostRegressor is:",(r2_score(y_test,pred_ada)- score.mean())*100)
# Out:
# [-9.4061111  -5.86547172 -4.01220885 -5.66318324 -6.52309812]
# -6.294014606684572
# Difference between cross validation score and R2 score at AdaBoostRegressor is: -15.229268853012389

# %% [markdown]
# # conclusion
# From the differnece between R2 score and cross validation score we can conclude that DecisionTreeRegressor is our best fitted model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters= {'criterion':['squared_error', 'absolute_error', 'poisson'],
            'splitter': ['best', 'random'],
            'min_samples_leaf':[5,10,15,100],
            'random_state':[20,30,50]}

# %%
GCV=GridSearchCV(DecisionTreeRegressor(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'min_samples_leaf': [5, 10, 15, 100],
#                          'random_state': [20, 30, 50],
#                          'splitter': ['best', 'random']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'poisson',
#  'min_samples_leaf': 5,
#  'random_state': 50,
#  'splitter': 'best'}

# %%
Final_model = DecisionTreeRegressor(criterion = 'poisson', min_samples_leaf = 5,random_state = 50, splitter = 'best')
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_score:', r2_score(y_test, pred))
print("Mean_absolute_error:", mean_absolute_error(y_test,pred))
print("Mean Squared Error:", mean_squared_error(y_test,pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7833087693632828
# Mean_absolute_error: 0.5071128472222222
# Mean Squared Error: 0.375742058121142
# Root Mean Squared Error: 0.6129780241747187

# %% [markdown]
# So the best R2 score for the final model is 78.33%

# %% [markdown]
# # Saving the model

# %%
#saving the model using.pkl
import joblib
joblib.dump(Final_model, "Happiness score.pkl")
# Out:
# ['Happiness score.pkl']
