# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Medical%20Cost%20Insurance/medical_cost_insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# This dataset contains 1338 rows and 7 columns, in which 'charges' are the target variable, and the remaining 6 columns are independent variable.This datasets contain the both that is categorical data and numerical data as well

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# this datasets contains 1338 rows and 7 columns, and having both categorical and numerical data

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
#checking the types of columns
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# There are three different types of data(int, object, float)present in the data

# %%
#checking the null values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# As we can see that there is no null values are present in the dataset.
# now lets visualize it using heat map

# %%
#visualising using heat map
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# we can clearly visualize that there is no misssing data

# %%
#checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# no     1064
# yes     274
# Name: smoker, dtype: int64
#
#
# southeast    364
# ...

# %%
# seprating numerical and categorical column

categorical_column=[]
for i in df.dtypes.index:
    if df.dtypes[i]== 'object':
        categorical_column.append(i)
print("Categorical Columns:", categorical_column)
print("\n")

#checking for numericals columns
numerical_column=[]
for i in df.dtypes.index:
    if df.dtypes[i]!= 'object':
        numerical_column.append(i)
print("Numerical Columns", numerical_column)
# Out:
# Categorical Columns: ['sex', 'smoker', 'region']
#
#
# Numerical Columns ['age', 'bmi', 'children', 'charges']

# %%
#checking number of unique values in each column
df.nunique().to_frame("No. of Unique values")
# Out:
#           No. of Unique values
# age                         47
# sex                          2
# bmi                        548
# children                     6
# smoker                       2
# region                       4
# charges                   1337

# %% [markdown]
# # Description of Datasets

# %%
#stastical summary of the the dataset
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# From the above statstical summary, we can observe that there is no negative value in the dataset, so it is a perfect dataset.
# also we observe that
#
# 1) The counts of all the columns are same which means there are no missing values in the dataset.
# 2) as there is difference between 75% and max values of column named, age,bmi, and children column, it means outliers are present in these columns.
# 3) as we see that there is difference in 75% and max values but we can ignore the values of this column as it is our target column

# %% [markdown]
# # Data Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#Visualization for numerical columns

plt.figure(figsize= (20,25))
plotnumber = 1

for column in numerical_column:
    if plotnumber<=8:
        ax = plt.subplot(3,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above distribution plot we can see that the column bmi is little skewed to the right side, and the column children is skewed to the right side. As the charges column is our target column, so we can not do anything to it.

# %%
# data visualization for categorial column

#visualization for column sex
ax = sns.countplot(x='sex',data=df)
print(df['sex'].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# From the above graph we can see that male customers are little bit more than female customers.

# %%
#visualization for smoker customers
ax = sns.countplot(x='smoker', data=df)
print(df['smoker'].value_counts())
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %% [markdown]
# From the above graph we can see that the number of non smoker customers are more than somker customers.

# %%
#visualization for region
ax= sns.countplot(x='region', data= df)
print(df['region'].value_counts())
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# From the above graph we can see that the maximum insured persons are residing in south east region

# %% [markdown]
# # converting categorical column into numerical column

# %%
#enconding categorical column using ordinal encoding
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]= OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Checking outliers for the numerical column

# %%
plt.figure(figsize= (20,15), facecolor='white')
plotnumber = 1
for column in df:
    if plotnumber<=8:
        ax = plt.subplot(4,4, plotnumber)
        sns.boxplot(df[column], palette = 'Set2_r')
        plt.xlabel(column, fontsize=20)
        plt.yticks(rotation = 0, fontsize = 20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# we can see the otliers in the columns bmi and charges.
# but as charges is our target column, we cannot do anything to it.
# we will try to remove the outliers from bmi column.

# %% [markdown]
# so now removing outlier using zscore method

# %%
from scipy.stats import stats

z= np.abs(stats.zscore(df['bmi']))
print(z)
# Out:
# 0       0.453320
# 1       0.509621
# 2       0.383307
# 3       1.305531
# 4       0.292556
#           ...
# 1333    0.050297
# 1334    0.206139
# 1335    1.014878
# 1336    0.797813
# 1337    0.261388
# Name: bmi, Length: 1338, dtype: float64

# %%
threshold_z = 2
outlier = np.where(z > threshold_z)[0]
outlier
# Out:
# array([  28,  116,  128,  172,  198,  232,  250,  286,  292,  356,  380,
#         383,  401,  410,  412,  428,  438,  442,  454,  493,  521,  543,
#         547,  549,  563,  572,  582,  660,  674,  680,  701,  796,  811,
#         821,  847,  860,  867,  895,  930,  941,  950,  951, 1024, 1029,
#        1047, 1074, 1085, 1088, 1131, 1133, 1156, 1205, 1226, 1286, 1312,
#        1317, 1332], dtype=int64)

# %%
df1 = df.drop(outlier)
df1.shape
# Out:
# (1281, 7)

# %%
print("Data loss percentage- ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  4.260089686098654

# %%
df1
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1281 rows x 7 columns]

# %% [markdown]
# now using IQR method

# %%
#now using IQR method

#1st quantile
Q1 = df['bmi'].quantile(0.25)

#3rd quantile
Q3 = df['bmi'].quantile(0.75)

#IQR
IQR = Q3 - Q1

df2= df[~((df <(Q1 - 1.5 * IQR))|(df> (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (0, 7)

# %%
print("Data loss percentage- ",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  100.0

# %% [markdown]
# As we see that zscor method will give less number of loss data, so we use df1 as our new dataframe

# %%
df=df1

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1281 rows x 7 columns]

# %% [markdown]
# Checking how the data has been distributed in each column

# %%
plt.figure(figsize=(20,25), facecolor="Blue")

p=1
for column in df:
    if p<=9:
        ax= plt.subplot(3,4,p)
        sns.distplot(df[column],color="g" )
        plt.xlabel(column,fontsize=25)
    p+=1
plt.show()

# %% [markdown]
# From the above graph we can see that there is a skewness in the column children and smoker.
# but smoker is categorical column so no need to remove the skewness.

# %% [markdown]
# # checking for the skewness

# %%
df.skew()
# Out:
# age         0.051856
# sex        -0.020321
# bmi         0.085755
# children    0.938454
# smoker      1.472755
# region     -0.023184
# charges     1.486650
# dtype: float64

# %% [markdown]
# Removing skewness using cuberoot method

# %%
#removing skewness from column children
df['children']= np.cbrt(df['children'])

# %%
df.skew()
# Out:
# age         0.051856
# sex        -0.020321
# bmi         0.085755
# children   -0.080708
# smoker      1.472755
# region     -0.023184
# charges     1.486650
# dtype: float64

# %%
# lets visualize how data is looked after remving skewness from column children
sns.distplot(df['children'], color="r", kde_kws = {"shade":True},hist = False)
plt.show()

# %% [markdown]
# # correlation  between target variable and independent variable

# %%
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.012579  0.105321  0.054151 -0.018814 -0.003572  0.305545
# sex      -0.012579  1.000000  0.034668  0.017763  0.085962  0.000961  0.068727
# bmi       0.105321  0.034668  1.000000 -0.006158  0.004448  0.119384  0.201364
# children  0.054151  0.017763 -0.006158  1.000000  0.004566  0.008088  0.075246
# smoker   -0.018814  0.085962  0.004448  0.004566  1.000000 -0.002188  0.784990
# region   -0.003572  0.000961  0.119384  0.008088 -0.002188  1.000000 -0.014493
# charges   0.305545  0.068727  0.201364  0.075246  0.784990 -0.014493  1.000000

# %% [markdown]
# now we can visualize this correlation using heatmap

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2,linecolor='red',cmap='Spectral')
plt.xlabel('Figure',fontsize=30)
plt.title('Descriptive graph', fontsize=40)
plt.show()

# %% [markdown]
# From the above Heatmap we can observe that
# 1) the column charges has strong positive relation with the column smoker.
# 2) The column charges has least relation with the column region

# %%
#visualizing the correlation between target and label using bar plot
plt.figure(figsize=(22,8))
df.corr()['charges'].sort_values(ascending=False).drop(['charges']).plot(kind="bar",color="g")
plt.xlabel("Feature", fontsize = 17)
plt.ylabel("Target", fontsize= 17)
plt.title("correlation between label and feature", fontsize = 23)
plt.show()

# %% [markdown]
# From the above graph we can see that the column region has very less correlation with the target variable.

# %% [markdown]
# # seprating Feature and Label Column

# %%
#seprating feature and label into x and y variable
x = df.drop("charges", axis=1)
y = df["charges"]

print("Feature Dimension =", x.shape)
print("Target Dimension =", y.shape)
# Out:
# Feature Dimension = (1281, 6)
# Target Dimension = (1281,)

# %% [markdown]
# # Feature scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.441817 -1.010200 -0.467737 -1.108077  1.976878  1.344506
# 1    -1.512906  0.989903  0.617543  0.509690 -0.505848  0.441827
# 2    -0.802014  0.989903  0.475181  1.225146 -0.505848  0.441827
# 3    -0.446569  0.989903 -1.428220 -1.108077 -0.505848 -0.460853
# 4    -0.517658  0.989903 -0.286549 -1.108077 -0.505848 -0.460853
# ...        ...       ...       ...       ...       ...       ...
# 1276  0.761947  0.989903  0.099862  1.225146 -0.505848 -0.460853
# 1277 -1.512906 -1.010200  0.275504 -1.108077 -0.505848 -1.363532
# 1278 -1.512906 -1.010200  1.186991 -1.108077 -0.505848  0.441827
# 1279 -1.299638 -1.010200 -0.855998 -1.108077 -0.505848  1.344506
# 1280  1.543928 -1.010200 -0.251421 -1.108077  1.976878 -0.460853
#
# [1281 rows x 6 columns]

# %% [markdown]
# We have scaled the data using standard scalarization to overcome the issue of biasness.

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#    VIF values  Features
# 0    1.015234       age
# 1    1.009215       sex
# 2    1.027665       bmi
# 3    1.003558  children
# 4    1.007800    smoker
# 5    1.014849    region

# %% [markdown]
# From the above we can see that there are no columns who are more than the threshold value, so it means that there is no multicolinerity problem.

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Finding the best random state

# %%
# creating train tes split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=40, random_state=i)
    lr= LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is", maxAccu,"On Random State", maxRs)
# Out:
# Maximum r2 score is 0.898934596258641 On Random State 62
