# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing Dataset

# %%
df= pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# In the above dataframe the column name 'quality' is our target value and the rest of the columns are featured columns that we can use to predict are target value.  so it is a classification problem.

# %%
df.head(15)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
#checking the dimension of the dataset
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# This datasets contains 1599 rows and 12 columns out of which one is target variable and the remaining 11 columns are independent variables

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
#checking the types of the columns 
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
#checking the null values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# As we can see that there is no null values present in the dataset

# %%
#lets visualize it using the heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# It is clearly visualize that there is no null values present in the dataset

# %%
# checking the value counts of each columns

for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
#
#
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
#
#
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
#
#
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
#
#
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# ...

# %% [markdown]
# # Description of Dataset

# %%
#stastical summary of the columns

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# This gives the statstical information of the columns. As there are no negative values this means this dataset is a perfect dataset
#  From the above description  we can observe the folllowing:
#
#  1) As the count of all the columns are same, it means no values are missing in the dataset
#  2) The mean values in the 'fixed acidity' and 'Total sulfur dioxide'are  more than the median value, it means that the data is skewed to the right side.
#  3) We can observed that there are a huge  difference between the 75% and the max value of the columns named fixed acidity, residual sugar, free sulfur dioxide, total sulfer dioxide, it means outliers are present in the data.

# %% [markdown]
# #Data visualization

# %%
# visualize the quality data

ax= sns.countplot(x='quality', data=df)
print(df['quality'].value_counts())
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# In the above data visualization we can observe that the data for quality 5 and 6 is more higher than the data of quality of the other part.This will leads to class imbalance issue in the data, we will rectified it later.

# %%
# now we compare all the feature data with our target data

index=0
labels = df['quality']
features = df.drop('quality', axis=1)

for col in features.items():
    plt.figure(figsize=(10,5))
    sns.barplot(x=labels, y=col[index], data=df, color="deeppink")
plt.tight_layout()
plt.show()

# %% [markdown]
# we can observed  the following points from the  above barplot
# * In fixed acidity bar plot there is no fixed pattern
# * In volatile acidity the bar is decreasing till quality data 7 then its increased,
# * In citric acid the value is increasing from lower to higher quality data.
# * In residual sugar there is no fixed pattern
# * in chlorides there is no fixed pattern
# * In free sulfur dioxide also there is no fixed pattern
# * in total sulfur dioxide firstly the quality value is increasing and then its decreasing
# * in density the data is constant for all the quality values
# * in ph value the quality is not fixed
# * in sulphates the data is increasing
# * in alcolhol firstly the data is increasing and decreasing but after that it is continuously incrasing.
# so finally we conclude that citric acid, sulpahtes and alcohol is playing a major role in inproving the quality of the wine.

# %% [markdown]
# #  checking for the outliers

# %%
# cheking the outliers with the help of boxplot

plt.figure(figsize= (20,15), facecolor='white')
plotnumber = 1
for column in df:
    if plotnumber<=12:
        ax = plt.subplot(3,4, plotnumber)
        sns.boxplot(df[column], palette = 'Set2_r')
        plt.xlabel(column, fontsize=20)
        plt.yticks(rotation = 0, fontsize = 20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see that the outliers in all the columns,so now we can remove these outliers

# %%
#divide dataset into feature and label
y= df['quality']
x=df.drop(columns = ['quality'])

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# so now removing outliers using zscore and iqr techniques

# %%
from scipy.stats import zscore
out_features= x
z=np.abs(zscore(x))
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360          0.961877     1.391472        0.453218   0.243707
# 1          0.298547          1.967442     1.391472        0.043416   0.223875
# 2          0.298547          1.297065     1.186070        0.169427   0.096353
# 3          1.654856          1.384443     1.484154        0.453218   0.264960
# 4          0.528360          0.961877     1.391472        0.453218   0.243707
# ...             ...               ...          ...             ...        ...
# 1594       1.217796          0.403229     0.980669        0.382271   0.053845
# 1595       1.390155          0.123905     0.877968        0.240375   0.541259
# 1596       1.160343          0.099554     0.723916        0.169427   0.243707
# 1597       1.390155          0.654620     0.775267        0.382271   0.264960
# 1598       1.332702          1.216849     1.021999        0.752894   0.434990
#
# ...

# %%
#treshold=3
np.where(z>3)
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#           45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#          106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#          151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#          244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#          354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#          467,  480,  480,  494,  515,  544,  554,  554,  555,  555,  557,
#          557,  568,  584,  588,  591,  595,  608,  614,  636,  639,  649,
#          649,  651,  652,  652,  652,  672,  672,  684,  690,  692,  692,
#          695,  723,  724,  730,  754,  776,  777,  795,  821,  836,  837,
#          889,  911,  917,  923,  925,  926,  982, 1017, 1018, 1043, 1051,
#         1051, 1071, 1074, 1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154,
#         1165, 1175, 1186, 1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269,
# ...

# %%
#now removing the data above zscore and creating new dataframe
df1= df[(z<3).all(axis=1)]

df1.shape
# Out:
# (1458, 12)

# %%
print("Data loss percentage- ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  8.818011257035648

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#now using IQR method

#1st quantile
Q1 = x.quantile(0.25)

#3rd quantile
Q3 = x.quantile(0.75)

#IQR
IQR = Q3 - Q1

df2= df[~((df <(Q1 - 1.5 * IQR))|(df> (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (1194, 12)

# %%
print("Data loss percentage- ",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  25.328330206378986

# %% [markdown]
# As we see that the zscore method will give the less amount of loss percentage data so we used df1 as our new dataframe

# %%
df=df1

# %%
#Now checking the skewness of the data
df.skew()
# Out:
# fixed acidity           0.820879
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          2.450707
# chlorides               2.307274
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                 0.248823
# dtype: float64

# %% [markdown]
# As we see that there is a skewness present in the fixed acidity, residual sugar, chlorides,free sulfer dioxide, total sulfer dioxide, sulphates, and in alcohol. now we try to remove these skewness using log transformation method.

# %%
# removing skewness from fixed acidity column
df['fixed acidity']= np.log10(df['fixed acidity'])

# %%
df.skew()
# Out:
# fixed acidity           0.377100
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          2.450707
# chlorides               2.307274
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                 0.248823
# dtype: float64

# %% [markdown]
# As we see that we remove the skewness from fixed acidity column

# %%
#removing skewness from residual sugar column
df['residual sugar']= np.log10(df['residual sugar'])

# %%
df.skew()
# Out:
# fixed acidity           0.377100
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          1.229070
# chlorides               2.307274
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                 0.248823
# dtype: float64

# %%
#using log method
#df1['residual sugar']= np.log(df['residual sugar'])

# %%
#df.skew()

# %%
#using cuberoot method
#df['residual sugar']= np.cbrt(df['residual sugar'])

# %%
#df.skew()

# %%
#using square root method
#df['residual sugar']= np.sqrt(df['residual sugar'])

# %%
#df.skew()

# %% [markdown]
# after applying these much of transformation method to remove the skewness of the residual sugar, till also we are not able to get the acceptable range of skewness.

# %%
#removing skewness using log 10 method

df['chlorides']= np.log10(df['chlorides'])

# %%
df.skew()
# Out:
# fixed acidity           0.377100
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          1.229070
# chlorides               0.528828
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                 0.248823
# dtype: float64

# %%
# removing skewness from free sulfur dioxide using log10 method
df['free sulfur dioxide']= np.log10(df['free sulfur dioxide'])
df.skew()
# Out:
# fixed acidity           0.377100
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          1.229070
# chlorides               0.528828
# free sulfur dioxide    -0.300264
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                 0.248823
# dtype: float64

# %%
# removing skewness from total sulfer dioxide
df['total sulfur dioxide']= np.log10(df['total sulfur dioxide'])
df.skew()
# Out:
# fixed acidity           0.377100
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          1.229070
# chlorides               0.528828
# free sulfur dioxide    -0.300264
# total sulfur dioxide   -0.095735
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                 0.248823
# dtype: float64

# %%
#removing skewness from sulphates column
df['sulphates']= np.log10(df['sulphates'])
df.skew()
# Out:
# fixed acidity           0.377100
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          1.229070
# chlorides               0.528828
# free sulfur dioxide    -0.300264
# total sulfur dioxide   -0.095735
# density                 0.055543
# pH                      0.113039
# sulphates               0.345344
# alcohol                 0.757396
# quality                 0.248823
# dtype: float64

# %%
#removing skewness from alcohol column
df['alcohol']= np.log10(df['alcohol'])
df.skew()
# Out:
# fixed acidity           0.377100
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          1.229070
# chlorides               0.528828
# free sulfur dioxide    -0.300264
# total sulfur dioxide   -0.095735
# density                 0.055543
# pH                      0.113039
# sulphates               0.345344
# alcohol                 0.588835
# quality                 0.248823
# dtype: float64

# %%
#the final skewness table

df.skew()
# Out:
# fixed acidity           0.377100
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          1.229070
# chlorides               0.528828
# free sulfur dioxide    -0.300264
# total sulfur dioxide   -0.095735
# density                 0.055543
# pH                      0.113039
# sulphates               0.345344
# alcohol                 0.588835
# quality                 0.248823
# dtype: float64

# %%
plt.figure(figsize= (20,25))
plotnumber = 1

for column in df:
    if plotnumber<=12:
        ax = plt.subplot(3,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# As we can see that we remove the skewness from the columns.

# %% [markdown]
# # corelation between target variable and independent variable

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.295813     0.692400
# volatile acidity          -0.295813          1.000000    -0.589286
# citric acid                0.692400         -0.589286     1.000000
# residual sugar             0.204999          0.036963     0.188923
# chlorides                  0.232103          0.079752     0.104443
# free sulfur dioxide       -0.170132          0.046278    -0.107676
# total sulfur dioxide      -0.096951          0.099221    -0.027290
# density                    0.664021         -0.000446     0.372338
# pH                        -0.721165          0.252900    -0.521270
# sulphates                  0.190975         -0.356126     0.308570
# alcohol                   -0.039221         -0.212932     0.163495
# quality                    0.129743         -0.362783     0.238244
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# this gives the correlation between dependent and independent variables

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=15)
plt.title('Descriptive graph', fontsize=25)
plt.show()

# %% [markdown]
# From the above heatmap we can observe that:
# * the quality column has the positive corerelation with the alcohol column.
# * the target column has the negative corelation with the volatile acidity column.
# * also we can see that the column free sulfer dioxide and the column ph has very corelation with the target variable.
# * the column fixed acidity and citric acid, fixed acidity and density,free sulfur dioxide and total sulfer dioxide are highly positive corelated with each other.
# * the column fixed acidity and ph are negatively corealted with each other.

# %%
#visualizing the correlation between target and label using bar plot
plt.figure(figsize=(22,8))
df.corr()['quality'].sort_values(ascending=False).drop(['quality']).plot(kind="bar",color="g")
plt.xlabel("Feature", fontsize = 17)
plt.ylabel("Target", fontsize= 17)
plt.title("correlation between label and feature", fontsize = 23)
plt.show()

# %% [markdown]
# from the above barplot we can see that column residual sugar will have very less correlation.

# %% [markdown]
# # Label Binarize

# %%
# as per the statement 1 is for good quality, 0 is for quality

y=y.apply(lambda y_value:1 if y_value>7 else 0)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# # Feature scaling and standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1         -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2         -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3          1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# ...             ...               ...          ...             ...        ...
# 1594      -1.217796          0.403229    -0.980669       -0.382271   0.053845
# 1595      -1.390155          0.123905    -0.877968       -0.240375  -0.541259
# 1596      -1.160343         -0.099554    -0.723916       -0.169427  -0.243707
# 1597      -1.390155          0.654620    -0.775267       -0.382271  -0.264960
# 1598      -1.332702         -1.216849     1.021999        0.752894  -0.434990
#
# ...

# %% [markdown]
# We have scaled the data using standard scalarization method to overcome the issue of biasness

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values              Features
# 0     7.767512         fixed acidity
# 1     1.789390      volatile acidity
# 2     3.128022           citric acid
# 3     1.702588        residual sugar
# 4     1.481932             chlorides
# 5     1.963019   free sulfur dioxide
# 6     2.186813  total sulfur dioxide
# 7     6.343760               density
# 8     3.329732                    pH
# 9     1.429434             sulphates
# 10    3.031160               alcohol

# %% [markdown]
# Here we can take Threshold Value as '5'
#
# by checking VIF values we can find the feature causing the multicollinarity problem.
# here we can find that fixed acidity and density haveVIF value greater than 5.so we will drop one of the column first,if the same problem persist  then we will trying to remove other higher vif value column.

# %%
#dropping fixed acidity column
x.drop("fixed acidity", axis=1, inplace=True)

# %%
#again checking vif values
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#    VIF values              Features
# 0    1.784963      volatile acidity
# 1    2.780557           citric acid
# 2    1.386375        residual sugar
# 3    1.401232             chlorides
# 4    1.939209   free sulfur dioxide
# 5    2.069396  total sulfur dioxide
# 6    2.430096               density
# 7    1.610775                    pH
# 8    1.396382             sulphates
# 9    2.136067               alcohol

# %% [markdown]
# so we have solved multicollineraity problem.we can now move ahed for model building

# %%
y.value_counts()
# Out:
# 0    1581
# 1      18
# Name: quality, dtype: int64

# %% [markdown]
# Here we can see that data is not balanced, so we will balance it with oversampling method

# %% [markdown]
# # oversampling

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
SM= SMOTE()
x1,y1 = SM.fit_resample(x,y)

# %%
#checking the value count of target column
y.value_counts()
# Out:
# 0    1581
# 1      18
# Name: quality, dtype: int64

# %%
y1.value_counts()
# Out:
# 0    1581
# 1    1581
# Name: quality, dtype: int64

# %% [markdown]
# Now the data is balanced,so we can build Machine Learning models

# %% [markdown]
# # Modelling

# %% [markdown]
# Finding the best random State

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu = 0
maxRs=0
for i in range(1,200):
    x_train, x_test, y_train,y_test = train_test_split(x1,y1,test_size=0.30, random_state = i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc = accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs= i
print("Best accuracy is", maxAccu, "at random_state", maxRs)
# Out:
# Best accuracy is 0.9978925184404637 at random_state 41

# %% [markdown]
# The best accuracy score is 99.78% at the Random State 41

# %% [markdown]
# Creating train test split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.30, random_state= maxRs)

# %% [markdown]
# # Classification algorithemes

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# RandomForestClassifier

# %%
#checking accuracy for RandomForestClassifier
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.9895833333333334
# [[474   0]
#  [  5   1]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       474
#            1       1.00      0.17      0.29         6
#
#     accuracy                           0.99       480
#    macro avg       0.99      0.58      0.64       480
# weighted avg       0.99      0.99      0.99       480

# %% [markdown]
# The accuracy for this model is 98.9%

# %% [markdown]
# LogisticRegression

# %%
#checking accuracy for Logistic Regression
LR = LogisticRegression()
LR.fit(x_train, y_train)
predLR = LR.predict(x_test)
print(accuracy_score(y_test, predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.9833333333333333
# [[472   2]
#  [  6   0]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       474
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.98       480
#    macro avg       0.49      0.50      0.50       480
# weighted avg       0.98      0.98      0.98       480

# %% [markdown]
# The accuracy value of this model is 99.3%

# %% [markdown]
# SupportVectorMachineClassifier

# %%
#Checking accuracy for SupportVectorMachine classifier
svc = SVC()
svc.fit(x_train, y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test, predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.9875
# [[474   0]
#  [  6   0]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       474
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.99       480
#    macro avg       0.49      0.50      0.50       480
# weighted avg       0.98      0.99      0.98       480

# %% [markdown]
# The accuracy for this model is 98.7%

# %% [markdown]
# GradientBoostingClassifier

# %%
#checking accuracy for GradientBoostingClassifier
GB = GradientBoostingClassifier()
GB.fit(x_train, y_train)
predGB = GB.predict(x_test)
print(accuracy_score(y_test, predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.9854166666666667
# [[472   2]
#  [  5   1]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       474
#            1       0.33      0.17      0.22         6
#
#     accuracy                           0.99       480
#    macro avg       0.66      0.58      0.61       480
# weighted avg       0.98      0.99      0.98       480

# %% [markdown]
# The accuracy for this model is 98.75%

# %% [markdown]
# AdaBoostClassifier

# %%
#checking accuracy for AdaBoostClassifier
ABC = AdaBoostClassifier()
ABC.fit(x_train, y_train)
predABC = ABC.predict(x_test)
print(accuracy_score(y_test, predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
# Out:
# 0.9895833333333334
# [[474   0]
#  [  5   1]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       474
#            1       1.00      0.17      0.29         6
#
#     accuracy                           0.99       480
#    macro avg       0.99      0.58      0.64       480
# weighted avg       0.99      0.99      0.99       480

# %% [markdown]
# The accuracy score for this model is 98.9%

# %% [markdown]
# ExtraTreesClassifier

# %%
#checking accuracy using ExtraTreesClassifier
ET = ExtraTreesClassifier()
ET.fit(x_train, y_train)
predET = ET.predict(x_test)
print(accuracy_score(y_test, predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.9875
# [[473   1]
#  [  5   1]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       474
#            1       0.50      0.17      0.25         6
#
#     accuracy                           0.99       480
#    macro avg       0.74      0.58      0.62       480
# weighted avg       0.98      0.99      0.98       480

# %% [markdown]
# The accuracy score for this model is 98.75%

# %% [markdown]
# bagging classifier

# %%
#checking accuracy using baggingClassifier
BC = BaggingClassifier()
BC.fit(x_train, y_train)
predBC = BC.predict(x_test)
print(accuracy_score(y_test, predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.9854166666666667
# [[472   2]
#  [  5   1]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       474
#            1       0.33      0.17      0.22         6
#
#     accuracy                           0.99       480
#    macro avg       0.66      0.58      0.61       480
# weighted avg       0.98      0.99      0.98       480

# %% [markdown]
# The accuracy score for this model is 98.12%

# %% [markdown]
# cross validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
#checking cv for Random Forest Classifier
score= cross_val_score(RFC, x1,y1)
print(score)
print(score.mean())
print("Difference between Accureacy Score and Cross Validation Score is- ", accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.99210111 0.97946288 0.99683544 0.97468354 0.99208861]
# 0.9870343151958725
# Difference between Accureacy Score and Cross Validation Score is-  0.00254901813746089

# %%
#checking cv score for Logistic Regression
score= cross_val_score(LR, x1,y1)
print(score)
print(score.mean())
print("Difference between Accureacy Score and Cross Validation Score is- ", accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.97946288 0.90521327 0.92405063 0.84968354 0.93829114]
# 0.9193402923590698
# Difference between Accureacy Score and Cross Validation Score is-  0.0639930409742635

# %%
#checking cv for GradientBoostingClassifier
score= cross_val_score(GB, x1,y1)
print(score)
print(score.mean())
print("Difference between Accureacy Score and Cross Validation Score is- ", accuracy_score(y_test,predGB)-score.mean())
# Out:
# [0.99210111 0.96840442 0.98892405 0.9556962  0.9778481 ]
# 0.9765947767312577
# Difference between Accureacy Score and Cross Validation Score is-  0.008821889935409

# %%
#checking cv for SupportVectorClassifier
score= cross_val_score(svc, x1,y1)
print(score)
print(score.mean())
print("Difference between Accureacy Score and Cross Validation Score is- ", accuracy_score(y_test,predsvc)-score.mean())
# Out:
# [0.98894155 0.94944708 0.95727848 0.89873418 0.97468354]
# 0.9538169656248126
# Difference between Accureacy Score and Cross Validation Score is-  0.03368303437518749

# %%
#checking cv for AdaBoostingClassifier
score= cross_val_score(ABC, x1,y1)
print(score)
print(score.mean())
print("Difference between Accureacy Score and Cross Validation Score is- ", accuracy_score(y_test,predABC)-score.mean())
# Out:
# [0.9778831  0.95418641 0.97310127 0.94303797 0.96044304]
# 0.961730357749915
# Difference between Accureacy Score and Cross Validation Score is-  0.02785297558341837

# %%
#checking cv for BaggingClassifier
score= cross_val_score(BC, x1,y1)
print(score)
print(score.mean())
print("Difference between Accureacy Score and Cross Validation Score is- ", accuracy_score(y_test,predBC)-score.mean())
# Out:
# [0.98736177 0.97946288 0.98259494 0.96993671 0.98259494]
# 0.9803902453656488
# Difference between Accureacy Score and Cross Validation Score is-  0.005026421301017936

# %%
#checking cv for ExtraTreesClassifier
score= cross_val_score(ET, x1,y1)
print(score)
print(score.mean())
print("Difference between Accureacy Score and Cross Validation Score is- ", accuracy_score(y_test,predET)-score.mean())
# Out:
# [0.99842022 0.98262243 1.         0.97626582 0.99050633]
# 0.989562961185434
# Difference between Accureacy Score and Cross Validation Score is-  -0.0020629611854339203

# %% [markdown]
# ExtraTrees Classifier is our Best model as the difference between accuracy score and Cross validation score is least.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#extra trees classifier
from sklearn.model_selection import GridSearchCV

parameters = {'criterion': ['gini','entropy'],
             'max_depth':[0,10,20],
             'random_state':[10,50,1000],
             'n_jobs':[-2,-1, 1],
             'n_estimators':[50,100,150,200]}

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 150, 200],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'n_estimators': 50,
#  'n_jobs': -2,
#  'random_state': 10}

# %%
Final_model= ExtraTreesClassifier(criterion = 'entropy', max_depth= 20, n_estimators= 10,n_jobs =-2,random_state = 10)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
acc = accuracy_score(y_test, pred)
print(acc*100)
# Out:
# 98.75

# %%
Final_model= ExtraTreesClassifier(criterion = 'gini', max_depth= 10, n_estimators= 50,n_jobs =-2,random_state = 10)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
acc = accuracy_score(y_test, pred)
print(acc*100)
# Out:
# 98.75

# %% [markdown]
# # plotting ROC and AUC curve

# %%
from sklearn import metrics
fpr,tpr,thresholds = metrics.roc_curve(y_test, pred)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr= tpr, roc_auc= roc_auc,estimator_name= Final_model)
display.plot()

# %% [markdown]
# Here we draw the roc curve for our final model, and auc for our final model is 50%

# %% [markdown]
# # saving the model

# %%
#saving the model using.pkl
import joblib
joblib.dump(Final_model, "Wine Quality.pkl")
# Out:
# ['Wine Quality.pkl']
